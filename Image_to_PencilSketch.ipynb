# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayalakshmi12345/demo/blob/main/Image_to_PencilSketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %% [markdown]
# #reading image

# %%
image = cv2.imread("girl.jpg")

# %%
print(image)
# Out:
# [[[243 241 241]
#   [242 240 240]
#   [239 239 239]
#   ...
#   [244 241 237]
#   [244 241 237]
#   [245 242 238]]
#
#  [[243 241 241]
#   [242 240 240]
#   [239 239 239]
#   ...
#   [244 241 237]
#   [244 241 237]
#   [245 242 238]]
#
#  [[243 241 241]
#   [242 240 240]
#   [239 239 239]
#   ...
#   [244 241 237]
#   [245 242 238]
#   [245 242 238]]
#
#  ...
#
#  [[ 10   9  19]
#   [ 13  12  21]
#   [ 17  16  25]
#   ...
#   [ 14  16  17]
#   [ 14  16  17]
#   [ 14  16  17]]
#
#  [[ 10   9  19]
#   [ 13  12  21]
#   [ 17  16  25]
#   ...
#   [ 14  16  17]
#   [ 14  16  17]
#   [ 13  15  16]]
#
#  [[ 10   9  19]
#   [ 12  11  20]
#   [ 17  16  25]
#   ...
#   [ 14  16  17]
#   [ 13  15  16]
#   [ 13  15  16]]]

# %% [markdown]
# #converting BGR image to grayscale

# %%
gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %% [markdown]
# #image inversion

# %%
inverted_image = 255 - gray_image

# %%
from google.colab.patches import cv2_imshow

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=736x920 at 0x7F110F0DE250>
# <PIL.Image.Image image mode=L size=736x920 at 0x7F110F0DE210>
# -1

# %%
resized=cv2.resize(pencil_sketch,(500,500))

# %%
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7F110F09A450>
